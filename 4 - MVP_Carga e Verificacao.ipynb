# %% [markdown]
# **Carga e Verificação dos arquivos**

# %%
dbutils.fs.ls("/Volumes/workspace/default/csv")
# Out:
# [FileInfo(path='dbfs:/Volumes/workspace/default/csv/campeonato-brasileiro-cartoes.csv', name='campeonato-brasileiro-cartoes.csv', size=1416570, modificationTime=1766091031000),
#  FileInfo(path='dbfs:/Volumes/workspace/default/csv/campeonato-brasileiro-estatisticas-full.csv', name='campeonato-brasileiro-estatisticas-full.csv', size=1122235, modificationTime=1766091031000),
#  FileInfo(path='dbfs:/Volumes/workspace/default/csv/campeonato-brasileiro-full.csv', name='campeonato-brasileiro-full.csv', size=1136100, modificationTime=1766091031000),
#  FileInfo(path='dbfs:/Volumes/workspace/default/csv/campeonato-brasileiro-gols.csv', name='campeonato-brasileiro-gols.csv', size=471373, modificationTime=1766091031000)]
